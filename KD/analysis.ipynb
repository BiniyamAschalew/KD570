# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
temp_ablation = pd.read_csv('temperature_ablation.csv')
temp_ablation
# Out:
#     temperature  seed  accuracy
# 0            20     0     59.44
# 1            22     0     56.78
# 2            24     0     58.37
# 3            26     0     58.21
# 4            28     0     58.13
# 5            30     0     54.78
# 6            32     0     55.72
# 7            34     0     52.12
# 8            36     0     52.03
# 9            38     0     52.51
# 10           40     0     58.93
# 11           42     0     52.00
# 12           44     0     63.39
# 13           46     0     57.31
# 14           48     0     57.59
# 15           50     0     52.82
# 16           20     1     55.34
# 17           22     1     55.50
# 18           24     1     56.10
# 19           26     1     59.13
# 20           28     1     56.60
# 21           30     1     53.10
# 22           32     1     56.08
# 23           34     1     59.78
# 24           36     1     48.96
# 25           38     1     60.24
# 26           40     1     51.79
# 27           42     1     52.30
# ...

# %%
sns.barplot(x='seed', y='accuracy', hue='temperature', data=temp_ablation)
# Out:
# <Axes: xlabel='seed', ylabel='accuracy'>

# %%
temp_seed0 = temp_ablation[temp_ablation['seed'] == 0].reset_index(drop=True)
temp_seed1 = temp_ablation[temp_ablation['seed'] == 1].reset_index(drop=True)


conc_df = pd.concat([temp_seed0, temp_seed1], axis=1)
conc_df
# Out:
#     temperature  seed  accuracy  temperature  seed  accuracy
# 0            20     0     59.44           20     1     55.34
# 1            22     0     56.78           22     1     55.50
# 2            24     0     58.37           24     1     56.10
# 3            26     0     58.21           26     1     59.13
# 4            28     0     58.13           28     1     56.60
# 5            30     0     54.78           30     1     53.10
# 6            32     0     55.72           32     1     56.08
# 7            34     0     52.12           34     1     59.78
# 8            36     0     52.03           36     1     48.96
# 9            38     0     52.51           38     1     60.24
# 10           40     0     58.93           40     1     51.79
# 11           42     0     52.00           42     1     52.30
# 12           44     0     63.39           44     1     46.50
# 13           46     0     57.31           46     1     54.94
# ...
